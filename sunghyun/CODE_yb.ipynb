# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold

# %%
train = pd.read_csv('./train.csv').drop(columns=['ID'])
test = pd.read_csv('./test.csv').drop(columns=['ID'])

train.shape, test.shape
# Out:
# ((256351, 68), (90067, 67))

# %%
drop_columns2 = []
for col in train.columns:
  print(train[col].value_counts())
  if len(train[col].value_counts()) == 1:
    drop_columns2.append(col)
# Out:
# 시술 시기 코드
# TRDQAZ    38969
# TRCMWS    38090
# TRYBLT    36713
# TRVNRY    36173
# TRJXFG    36031
# TRZKPL    35544
# TRXQMD    34831
# Name: count, dtype: int64
# 시술 당시 나이
# 만18-34세    102476
# 만35-37세     57780
# 만38-39세     39247
# 만40-42세     37348
# 만43-44세     12253
# 만45-50세      6918
# 알 수 없음        329
# Name: count, dtype: int64
# 임신 시도 또는 마지막 임신 경과 연수
# 7.0     1214
# 8.0     1176
# 9.0     1023
# 6.0      991
# 10.0     947
# 11.0     701
# 5.0      692
# 12.0     510
# 13.0     481
# 14.0     331
# 4.0      305
# 15.0     254
# 16.0     202
# 17.0     140
# 18.0     106
# 3.0       89
# 19.0      86
# 20.0      83
# 2.0       21
# 0.0       12
# 1.0        6
# Name: count, dtype: int64
# 시술 유형
# IVF    250060
# DI       6291
# Name: count, dtype: int64
# 특정 시술 유형
# ICSI                                   122368
# IVF                                     91755
# Unknown                                 26939
# IUI                                      6100
# ICSI:ICSI                                2314
# ICSI / BLASTOCYST                        1609
# IVF / BLASTOCYST                         1248
# IVF:IVF                                  1146
# ICSI:IVF                                  873
# ICSI / AH                                 769
# IVF:ICSI                                  392
# IVF / AH                                  319
# ICSI:Unknown                              207
# IVF:Unknown                               100
# ICI                                        96
# Generic DI                                 71
# IVI                                        23
# ICSI / BLASTOCYST:IVF / BLASTOCYST          6
# ICSI / BLASTOCYST :IVF / BLASTOCYST         4
# FER                                         3
# IVF / AH:ICSI / AH                          2
# GIFT                                        2
# ICSI / AH:Unknown                           2
# ICSI / BLASTOCYST :ICSI                     1
# Name: count, dtype: int64
# 배란 자극 여부
# 1    197720
# 0     58631
# Name: count, dtype: int64
# 배란 유도 유형
# 기록되지 않은 시행      194432
# 알 수 없음           61917
# 세트로타이드 (억제제)         1
# 생식선 자극 호르몬           1
# Name: count, dtype: int64
# 단일 배아 이식 여부
# 0.0    191677
# 1.0     58383
# Name: count, dtype: int64
# 착상 전 유전 검사 사용 여부
# 1.0    2718
# Name: count, dtype: int64
# 착상 전 유전 진단 사용 여부
# 0.0    246864
# 1.0      3196
# Name: count, dtype: int64
# 남성 주 불임 원인
# 0    249041
# 1      7310
# Name: count, dtype: int64
# 남성 부 불임 원인
# 0    252989
# 1      3362
# Name: count, dtype: int64
# 여성 주 불임 원인
# 0    248475
# 1      7876
# Name: count, dtype: int64
# 여성 부 불임 원인
# 0    253164
# 1      3187
# Name: count, dtype: int64
# 부부 주 불임 원인
# 0    247874
# 1      8477
# Name: count, dtype: int64
# 부부 부 불임 원인
# 0    254104
# 1      2247
# Name: count, dtype: int64
# 불명확 불임 원인
# 0    192076
# 1     64275
# Name: count, dtype: int64
# 불임 원인 - 난관 질환
# 0    220794
# 1     35557
# Name: count, dtype: int64
# 불임 원인 - 남성 요인
# 0    160885
# 1     95466
# Name: count, dtype: int64
# 불임 원인 - 배란 장애
# 0    222925
# 1     33426
# Name: count, dtype: int64
# 불임 원인 - 여성 요인
# 0    256351
# Name: count, dtype: int64
# 불임 원인 - 자궁경부 문제
# 0    256341
# 1        10
# Name: count, dtype: int64
# 불임 원인 - 자궁내막증
# 0    238049
# 1     18302
# Name: count, dtype: int64
# 불임 원인 - 정자 농도
# 0    256075
# 1       276
# Name: count, dtype: int64
# 불임 원인 - 정자 면역학적 요인
# 0    256350
# 1         1
# Name: count, dtype: int64
# 불임 원인 - 정자 운동성
# 0    256254
# 1        97
# Name: count, dtype: int64
# 불임 원인 - 정자 형태
# 0    256208
# 1       143
# Name: count, dtype: int64
# 배아 생성 주요 이유
# 현재 시술용                 233732
# 배아 저장용                   9192
# 기증용, 현재 시술용              3784
# 난자 저장용                   1959
# 기증용                      1108
# 기증용, 배아 저장용               125
# 배아 저장용, 현재 시술용             83
# 기증용, 난자 저장용                44
# 기증용, 배아 저장용, 현재 시술용        20
# 난자 저장용, 배아 저장용              6
# 난자 저장용, 현재 시술용              5
# 연구용, 현재 시술용                 1
# 난자 저장용, 배아 저장용, 연구용         1
# Name: count, dtype: int64
# 총 시술 횟수
# 0회       97599
# 1회       56819
# 2회       39338
# 3회       24531
# 4회       15141
# 6회 이상    13817
# 5회        9106
# Name: count, dtype: int64
# 클리닉 내 총 시술 횟수
# 0회       121675
# 1회        59753
# 2회        34562
# 3회        18357
# 4회        10018
# 6회 이상      6590
# 5회         5396
# Name: count, dtype: int64
# IVF 시술 횟수
# 0회       103934
# 1회        58339
# 2회        39177
# 3회        23280
# 4회        13660
# 6회 이상     10159
# 5회         7802
# Name: count, dtype: int64
# DI 시술 횟수
# 0회       242464
# 3회         3116
# 2회         3006
# 1회         2920
# 6회 이상      1917
# 4회         1727
# 5회         1201
# Name: count, dtype: int64
# 총 임신 횟수
# 0회       205426
# 1회        43829
# 2회         6246
# 3회          746
# 4회           93
# 5회            8
# 6회 이상         3
# Name: count, dtype: int64
# IVF 임신 횟수
# 0회       208292
# 1회        41519
# 2회         5788
# 3회          663
# 4회           81
# 5회            7
# 6회 이상         1
# Name: count, dtype: int64
# DI 임신 횟수
# 0회    253302
# 1회      2625
# 2회       368
# 3회        48
# 4회         5
# 5회         3
# Name: count, dtype: int64
# 총 출산 횟수
# 0회       218555
# 1회        35369
# 2회         2242
# 3회          169
# 4회           13
# 6회 이상         2
# 5회            1
# Name: count, dtype: int64
# IVF 출산 횟수
# 0회    220831
# 1회     33348
# 2회      2021
# 3회       137
# 4회        13
# 5회         1
# Name: count, dtype: int64
# DI 출산 횟수
# 0회    254009
# 1회      2138
# 2회       183
# 3회        19
# 5회         2
# Name: count, dtype: int64
# 총 생성 배아 수
# 0.0     53349
# 4.0     21612
# 3.0     20952
# 5.0     20410
# 2.0     19190
# 6.0     18623
# 7.0     16029
# 1.0     15223
# 8.0     13620
# 9.0     11131
# 10.0     9065
# 11.0     7090
# 12.0     5720
# 13.0     4321
# 14.0     3360
# 15.0     2516
# 16.0     1916
# 17.0     1504
# 18.0     1117
# 19.0      799
# 20.0      640
# 21.0      461
# 22.0      354
# 23.0      266
# 24.0      195
# 25.0      163
# 26.0      105
# 27.0       84
# 28.0       51
# 29.0       46
# 30.0       40
# 31.0       25
# 32.0       23
# 34.0       15
# 33.0       12
# 37.0        7
# 36.0        7
# 35.0        4
# 42.0        3
# 38.0        3
# 44.0        3
# 51.0        2
# 41.0        2
# 40.0        1
# 43.0        1
# Name: count, dtype: int64
# 미세주입된 난자 수
# 0.0     127669
# 6.0      11075
# 5.0      10619
# 7.0      10411
# 8.0       9699
# 4.0       9622
# 9.0       8606
# 3.0       7912
# 10.0      7748
# 11.0      6528
# 2.0       6294
# 12.0      5622
# 13.0      4651
# 1.0       4537
# 14.0      3842
# 15.0      3191
# 16.0      2559
# 17.0      1964
# 18.0      1594
# 19.0      1224
# 20.0       997
# 21.0       796
# 22.0       656
# 23.0       489
# 24.0       363
# 25.0       281
# 26.0       241
# 27.0       185
# 28.0       165
# 29.0       113
# 30.0        92
# 31.0        60
# 32.0        52
# 33.0        39
# 34.0        35
# 35.0        31
# 36.0        27
# 37.0        14
# 38.0        11
# 40.0         8
# 43.0         7
# 39.0         7
# 51.0         5
# 45.0         4
# 46.0         3
# 42.0         3
# 41.0         3
# 47.0         2
# 48.0         1
# 49.0         1
# 44.0         1
# 50.0         1
# Name: count, dtype: int64
# 미세주입에서 생성된 배아 수
# 0.0     131772
# 4.0      13883
# 3.0      13806
# 5.0      12923
# 2.0      12631
# 6.0      11587
# 1.0       9917
# 7.0       9516
# 8.0       7789
# 9.0       6173
# 10.0      4819
# 11.0      3739
# 12.0      2981
# 13.0      2151
# 14.0      1689
# 15.0      1208
# 16.0       884
# 17.0       695
# 18.0       503
# 19.0       349
# 20.0       267
# 21.0       204
# 22.0       145
# 23.0       118
# 24.0        78
# 25.0        68
# 26.0        39
# 27.0        35
# 29.0        21
# 28.0        20
# 30.0        16
# 32.0         8
# 34.0         6
# 31.0         6
# 33.0         6
# 41.0         2
# 42.0         2
# 36.0         1
# 43.0         1
# 38.0         1
# 37.0         1
# Name: count, dtype: int64
# 이식된 배아 수
# 2.0    110845
# 1.0     93791
# 0.0     36544
# 3.0      8880
# Name: count, dtype: int64
# 미세주입 배아 이식 수
# 0.0    138774
# 2.0     59685
# 1.0     46475
# 3.0      5126
# Name: count, dtype: int64
# 저장된 배아 수
# 0.0     166866
# 1.0      20366
# 2.0      19879
# 3.0      13504
# 4.0       9249
# 5.0       5978
# 6.0       4114
# 7.0       2655
# 8.0       1877
# 9.0       1287
# 10.0      1014
# 11.0       634
# 12.0       535
# 13.0       396
# 14.0       345
# 15.0       254
# 16.0       197
# 17.0       179
# 18.0       170
# 20.0       109
# 19.0       100
# 21.0        75
# 22.0        67
# 23.0        67
# 24.0        38
# 25.0        32
# 26.0        16
# 27.0        12
# 30.0         9
# 28.0         8
# 29.0         7
# 32.0         4
# 34.0         3
# 41.0         2
# 51.0         2
# 36.0         2
# 37.0         2
# 31.0         2
# 42.0         1
# 38.0         1
# 33.0         1
# 44.0         1
# Name: count, dtype: int64
# 미세주입 후 저장된 배아 수
# 0.0     204294
# 1.0      12341
# 2.0      11351
# 3.0       7430
# 4.0       4872
# 5.0       3022
# 6.0       1938
# 7.0       1279
# 8.0        874
# 9.0        617
# 10.0       467
# 11.0       290
# 12.0       259
# 13.0       200
# 14.0       175
# 15.0       128
# 16.0       104
# 18.0        81
# 17.0        80
# 19.0        52
# 20.0        44
# 22.0        32
# 23.0        32
# 21.0        31
# 24.0        19
# 25.0        17
# 27.0         8
# 26.0         4
# 30.0         4
# 29.0         4
# 28.0         3
# 32.0         2
# 42.0         1
# 41.0         1
# 34.0         1
# 43.0         1
# 38.0         1
# 51.0         1
# Name: count, dtype: int64
# 해동된 배아 수
# 0.0     209675
# 1.0      13056
# 2.0      12075
# 3.0       5394
# 4.0       3452
# 5.0       1937
# 6.0       1499
# 7.0        819
# 8.0        751
# 9.0        412
# 10.0       344
# 11.0       156
# 12.0       144
# 13.0        81
# 14.0        75
# 16.0        47
# 15.0        42
# 17.0        27
# 18.0        24
# 19.0        16
# 21.0         7
# 22.0         6
# 20.0         5
# 26.0         5
# 23.0         5
# 24.0         4
# 30.0         1
# 32.0         1
# Name: count, dtype: int64
# 해동 난자 수
# 0.0     248615
# 8.0        219
# 6.0        171
# 7.0        143
# 4.0        130
# 5.0        107
# 9.0        105
# 10.0        91
# 12.0        70
# 11.0        67
# 2.0         65
# 3.0         65
# 14.0        44
# 15.0        37
# 13.0        32
# 1.0         26
# 16.0        20
# 17.0        14
# 19.0        12
# 18.0         7
# 20.0         5
# 24.0         3
# 23.0         2
# 21.0         2
# 26.0         2
# 32.0         1
# 25.0         1
# 36.0         1
# 33.0         1
# 27.0         1
# 22.0         1
# Name: count, dtype: int64
# 수집된 신선 난자 수
# 0.0     53845
# 8.0     13332
# 7.0     13092
# 9.0     12934
# 10.0    12757
# 6.0     12618
# 11.0    11980
# 5.0     11516
# 12.0    10942
# 4.0     10000
# 13.0     9884
# 14.0     9026
# 3.0      8149
# 15.0     7791
# 16.0     6774
# 2.0      6441
# 17.0     5763
# 18.0     4954
# 1.0      4854
# 19.0     4052
# 20.0     3476
# 21.0     2789
# 22.0     2293
# 23.0     1877
# 24.0     1646
# 25.0     1373
# 26.0     1036
# 27.0      851
# 28.0      728
# 29.0      554
# 30.0      500
# 31.0      373
# 32.0      344
# 33.0      269
# 34.0      223
# 35.0      183
# 36.0      157
# 37.0      132
# 38.0      104
# 40.0       76
# 51.0       65
# 39.0       64
# 42.0       49
# 41.0       45
# 43.0       31
# 46.0       26
# 44.0       24
# 45.0       23
# 47.0       16
# 50.0       13
# 49.0       11
# 48.0        5
# Name: count, dtype: int64
# 저장된 신선 난자 수
# 0.0     247394
# 5.0        217
# 6.0        214
# 4.0        204
# 3.0        201
# 2.0        189
# 8.0        183
# 7.0        180
# 10.0       147
# 9.0        147
# 1.0        145
# 11.0       122
# 12.0       115
# 14.0        88
# 13.0        86
# 15.0        79
# 16.0        57
# 17.0        50
# 18.0        50
# 19.0        30
# 20.0        22
# 22.0        21
# 23.0        18
# 21.0        17
# 24.0        15
# 25.0        14
# 27.0        12
# 26.0        10
# 28.0         6
# 32.0         5
# 30.0         4
# 29.0         4
# 34.0         3
# 35.0         3
# 31.0         2
# 36.0         1
# 33.0         1
# 46.0         1
# 37.0         1
# 40.0         1
# 51.0         1
# Name: count, dtype: int64
# 혼합된 난자 수
# 0.0     46650
# 6.0     16349
# 7.0     15973
# 5.0     15510
# 8.0     15253
# 9.0     14105
# 4.0     13603
# 10.0    13003
# 11.0    11588
# 3.0     11067
# 12.0    10188
# 2.0      8933
# 13.0     8717
# 14.0     7557
# 15.0     6510
# 1.0      6450
# 16.0     5319
# 17.0     4350
# 18.0     3547
# 19.0     2856
# 20.0     2408
# 21.0     1922
# 22.0     1597
# 23.0     1291
# 24.0     1048
# 25.0      836
# 26.0      652
# 27.0      537
# 28.0      449
# 29.0      324
# 30.0      279
# 31.0      199
# 32.0      189
# 33.0      151
# 34.0      122
# 35.0      110
# 36.0       83
# 37.0       71
# 38.0       61
# 39.0       36
# 40.0       33
# 51.0       29
# 42.0       22
# 41.0       17
# 43.0       17
# 46.0       12
# 44.0        9
# 47.0        8
# 45.0        7
# 49.0        5
# 50.0        5
# 48.0        3
# Name: count, dtype: int64
# 파트너 정자와 혼합된 난자 수
# 0.0     62921
# 6.0     15012
# 7.0     14706
# 5.0     14229
# 8.0     14070
# 9.0     13055
# 4.0     12416
# 10.0    12017
# 11.0    10713
# 3.0     10103
# 12.0     9463
# 2.0      8077
# 13.0     8043
# 14.0     7030
# 15.0     6028
# 1.0      5722
# 16.0     4898
# 17.0     4021
# 18.0     3293
# 19.0     2680
# 20.0     2222
# 21.0     1792
# 22.0     1477
# 23.0     1213
# 24.0      967
# 25.0      757
# 26.0      598
# 27.0      502
# 28.0      410
# 29.0      295
# 30.0      260
# 31.0      183
# 32.0      171
# 33.0      131
# 34.0      113
# 35.0      100
# 36.0       72
# 37.0       64
# 38.0       47
# 39.0       34
# 40.0       31
# 51.0       28
# 42.0       21
# 43.0       17
# 41.0       16
# 46.0       12
# 47.0        7
# 44.0        7
# 45.0        5
# 49.0        4
# 50.0        4
# 48.0        3
# Name: count, dtype: int64
# 기증자 정자와 혼합된 난자 수
# 0.0     234546
# 6.0       1366
# 5.0       1304
# 7.0       1256
# 4.0       1203
# 8.0       1166
# 9.0       1009
# 3.0        986
# 10.0       934
# 2.0        871
# 11.0       816
# 1.0        738
# 12.0       666
# 13.0       599
# 14.0       477
# 15.0       410
# 16.0       357
# 17.0       273
# 18.0       202
# 19.0       148
# 20.0       148
# 21.0       114
# 22.0        88
# 24.0        63
# 25.0        58
# 23.0        57
# 26.0        37
# 28.0        26
# 27.0        25
# 29.0        21
# 32.0        16
# 33.0        15
# 30.0        12
# 31.0        12
# 36.0         9
# 38.0         7
# 35.0         6
# 37.0         5
# 34.0         5
# 39.0         2
# 40.0         1
# 50.0         1
# 49.0         1
# 47.0         1
# 42.0         1
# 45.0         1
# 41.0         1
# Name: count, dtype: int64
# 난자 출처
# 본인 제공     234291
# 기증 제공      15769
# 알 수 없음      6291
# Name: count, dtype: int64
# 정자 출처
# 배우자 제공         229199
# 기증 제공           27016
# 미할당               122
# 배우자 및 기증 제공        14
# Name: count, dtype: int64
# 난자 기증자 나이
# 알 수 없음     242381
# 만31-35세      6366
# 만26-30세      4976
# 만21-25세      2334
# 만20세 이하       294
# Name: count, dtype: int64
# 정자 기증자 나이
# 알 수 없음     230518
# 만21-25세      5667
# 만36-40세      5282
# 만26-30세      5058
# 만31-35세      4911
# 만41-45세      3848
# 만20세 이하      1067
# Name: count, dtype: int64
# 동결 배아 사용 여부
# 0.0    209934
# 1.0     40126
# Name: count, dtype: int64
# 신선 배아 사용 여부
# 1.0    210136
# 0.0     39924
# Name: count, dtype: int64
# 기증 배아 사용 여부
# 0.0    247602
# 1.0      2458
# Name: count, dtype: int64
# 대리모 여부
# 0.0    249011
# 1.0      1049
# Name: count, dtype: int64
# PGD 시술 여부
# 1.0    2179
# Name: count, dtype: int64
# PGS 시술 여부
# 1.0    1929
# Name: count, dtype: int64
# 난자 채취 경과일
# 0.0    198863
# Name: count, dtype: int64
# 난자 해동 경과일
# 0.0    1434
# 1.0       2
# Name: count, dtype: int64
# 난자 혼합 경과일
# 0.0    201920
# 1.0       488
# 2.0       102
# 3.0        68
# 5.0        24
# 6.0         8
# 4.0         5
# 7.0         1
# Name: count, dtype: int64
# 배아 이식 경과일
# 5.0    81459
# 3.0    57924
# 2.0    35078
# 0.0    24904
# 1.0     6053
# 4.0     4504
# 6.0     2773
# 7.0       90
# Name: count, dtype: int64
# 배아 해동 경과일
# 0.0    39801
# 2.0      182
# 3.0      164
# 5.0      140
# 1.0       37
# 6.0       30
# 4.0       12
# 7.0        3
# Name: count, dtype: int64
# 임신 성공 여부
# 0    190123
# 1     66228
# Name: count, dtype: int64

# %%
for col in test.columns:
  print(test[col].value_counts())
# Out:
# 시술 시기 코드
# TRDQAZ    13610
# TRCMWS    13392
# TRYBLT    12929
# TRZKPL    12793
# TRJXFG    12764
# TRVNRY    12560
# TRXQMD    12019
# Name: count, dtype: int64
# 시술 당시 나이
# 만18-34세    36178
# 만35-37세    20211
# 만38-39세    13611
# 만40-42세    13266
# 만43-44세     4272
# 만45-50세     2413
# 알 수 없음       116
# Name: count, dtype: int64
# 임신 시도 또는 마지막 임신 경과 연수
# 7.0     405
# 8.0     403
# 6.0     352
# 9.0     320
# 10.0    311
# 5.0     286
# 11.0    253
# 12.0    205
# 13.0    168
# 14.0    127
# 4.0     106
# 15.0     92
# 16.0     64
# 17.0     64
# 18.0     44
# 20.0     33
# 19.0     29
# 3.0      23
# 2.0       5
# 0.0       4
# 1.0       3
# Name: count, dtype: int64
# 시술 유형
# IVF    87891
# DI      2176
# Name: count, dtype: int64
# 특정 시술 유형
# ICSI                                  43237
# IVF                                   32350
# Unknown                                9216
# IUI                                    2112
# ICSI:ICSI                               797
# ICSI / BLASTOCYST                       584
# IVF:IVF                                 406
# IVF / BLASTOCYST                        389
# ICSI:IVF                                298
# ICSI / AH                               264
# IVF:ICSI                                133
# IVF / AH                                105
# ICSI:Unknown                             68
# IVF:Unknown                              41
# ICI                                      28
# Generic DI                               26
# IVI                                       8
# ICSI / BLASTOCYST:IVF / BLASTOCYST        2
# IUI:ICI                                   2
# IVF:Unknown:Unknown:Unknown               1
# Name: count, dtype: int64
# 배란 자극 여부
# 1    69756
# 0    20311
# Name: count, dtype: int64
# 배란 유도 유형
# 기록되지 않은 시행    68599
# 알 수 없음        21468
# Name: count, dtype: int64
# 단일 배아 이식 여부
# 0.0    67431
# 1.0    20460
# Name: count, dtype: int64
# 착상 전 유전 검사 사용 여부
# 1.0    933
# Name: count, dtype: int64
# 착상 전 유전 진단 사용 여부
# 0.0    86754
# 1.0     1137
# Name: count, dtype: int64
# 남성 주 불임 원인
# 0    87459
# 1     2608
# Name: count, dtype: int64
# 남성 부 불임 원인
# 0    88908
# 1     1159
# Name: count, dtype: int64
# 여성 주 불임 원인
# 0    87324
# 1     2743
# Name: count, dtype: int64
# 여성 부 불임 원인
# 0    88930
# 1     1137
# Name: count, dtype: int64
# 부부 주 불임 원인
# 0    87067
# 1     3000
# Name: count, dtype: int64
# 부부 부 불임 원인
# 0    89286
# 1      781
# Name: count, dtype: int64
# 불명확 불임 원인
# 0    67458
# 1    22609
# Name: count, dtype: int64
# 불임 원인 - 난관 질환
# 0    77687
# 1    12380
# Name: count, dtype: int64
# 불임 원인 - 남성 요인
# 0    56560
# 1    33507
# Name: count, dtype: int64
# 불임 원인 - 배란 장애
# 0    78550
# 1    11517
# Name: count, dtype: int64
# 불임 원인 - 여성 요인
# 0    90067
# Name: count, dtype: int64
# 불임 원인 - 자궁경부 문제
# 0    90063
# 1        4
# Name: count, dtype: int64
# 불임 원인 - 자궁내막증
# 0    83626
# 1     6441
# Name: count, dtype: int64
# 불임 원인 - 정자 농도
# 0    89975
# 1       92
# Name: count, dtype: int64
# 불임 원인 - 정자 면역학적 요인
# 0    90066
# 1        1
# Name: count, dtype: int64
# 불임 원인 - 정자 운동성
# 0    90024
# 1       43
# Name: count, dtype: int64
# 불임 원인 - 정자 형태
# 0    90008
# 1       59
# Name: count, dtype: int64
# 배아 생성 주요 이유
# 현재 시술용                 82253
# 배아 저장용                  3151
# 기증용, 현재 시술용             1327
# 난자 저장용                   664
# 기증용                      384
# 기증용, 배아 저장용               47
# 배아 저장용, 현재 시술용            38
# 기증용, 난자 저장용               19
# 기증용, 배아 저장용, 현재 시술용        6
# 난자 저장용, 현재 시술용             1
# 난자 저장용, 배아 저장용             1
# Name: count, dtype: int64
# 총 시술 횟수
# 0회       34382
# 1회       20018
# 2회       13692
# 3회        8632
# 4회        5262
# 6회 이상     4793
# 5회        3288
# Name: count, dtype: int64
# 클리닉 내 총 시술 횟수
# 0회       42792
# 1회       20955
# 2회       12122
# 3회        6477
# 4회        3416
# 6회 이상     2257
# 5회        2048
# Name: count, dtype: int64
# IVF 시술 횟수
# 0회       36578
# 1회       20536
# 2회       13647
# 3회        8115
# 4회        4816
# 6회 이상     3566
# 5회        2809
# Name: count, dtype: int64
# DI 시술 횟수
# 0회       85304
# 3회        1109
# 1회        1021
# 2회         969
# 6회 이상      652
# 4회         555
# 5회         457
# Name: count, dtype: int64
# 총 임신 횟수
# 0회       72216
# 1회       15386
# 2회        2127
# 3회         297
# 4회          37
# 5회           3
# 6회 이상        1
# Name: count, dtype: int64
# IVF 임신 횟수
# 0회    73207
# 1회    14571
# 2회     1981
# 3회      274
# 4회       31
# 5회        3
# Name: count, dtype: int64
# DI 임신 횟수
# 0회    89008
# 1회      929
# 2회      117
# 3회       10
# 4회        2
# 5회        1
# Name: count, dtype: int64
# 총 출산 횟수
# 0회       76735
# 1회       12548
# 2회         727
# 3회          51
# 4회           5
# 6회 이상        1
# Name: count, dtype: int64
# IVF 출산 횟수
# 0회    77480
# 1회    11874
# 2회      666
# 3회       42
# 4회        5
# Name: count, dtype: int64
# DI 출산 횟수
# 0회    89296
# 1회      720
# 2회       46
# 3회        4
# 5회        1
# Name: count, dtype: int64
# 총 생성 배아 수
# 0.0     18474
# 4.0      7614
# 3.0      7530
# 5.0      7276
# 2.0      6737
# 6.0      6641
# 7.0      5568
# 1.0      5441
# 8.0      4740
# 9.0      3907
# 10.0     3110
# 11.0     2501
# 12.0     2012
# 13.0     1559
# 14.0     1154
# 15.0      861
# 16.0      685
# 17.0      538
# 18.0      394
# 19.0      286
# 20.0      228
# 21.0      162
# 22.0      132
# 23.0       86
# 24.0       70
# 25.0       50
# 26.0       33
# 27.0       28
# 28.0       20
# 30.0       10
# 29.0        8
# 32.0        8
# 31.0        7
# 35.0        4
# 34.0        4
# 37.0        2
# 33.0        2
# 42.0        1
# 39.0        1
# 44.0        1
# 36.0        1
# 45.0        1
# 43.0        1
# 38.0        1
# 40.0        1
# 49.0        1
# Name: count, dtype: int64
# 미세주입된 난자 수
# 0.0     44629
# 6.0      3880
# 5.0      3785
# 7.0      3724
# 4.0      3480
# 8.0      3452
# 9.0      3066
# 3.0      2821
# 10.0     2787
# 11.0     2249
# 2.0      2168
# 12.0     1972
# 13.0     1672
# 1.0      1612
# 14.0     1299
# 15.0     1082
# 16.0      881
# 17.0      746
# 18.0      555
# 19.0      453
# 20.0      337
# 21.0      286
# 22.0      204
# 23.0      150
# 24.0      134
# 25.0      108
# 26.0       75
# 27.0       58
# 28.0       50
# 29.0       35
# 31.0       29
# 30.0       27
# 32.0       20
# 33.0       15
# 34.0        9
# 36.0        7
# 38.0        6
# 35.0        6
# 37.0        5
# 41.0        3
# 46.0        2
# 43.0        2
# 44.0        2
# 40.0        2
# 45.0        1
# 49.0        1
# 48.0        1
# 39.0        1
# 51.0        1
# 42.0        1
# Name: count, dtype: int64
# 미세주입에서 생성된 배아 수
# 0.0     46013
# 4.0      4988
# 3.0      4886
# 5.0      4629
# 2.0      4450
# 6.0      4125
# 1.0      3565
# 7.0      3335
# 8.0      2743
# 9.0      2134
# 10.0     1716
# 11.0     1289
# 12.0     1043
# 13.0      777
# 14.0      573
# 15.0      417
# 16.0      338
# 17.0      252
# 18.0      173
# 19.0      120
# 20.0       90
# 21.0       66
# 22.0       50
# 23.0       34
# 24.0       26
# 25.0       18
# 26.0       13
# 27.0       10
# 28.0        8
# 32.0        3
# 39.0        1
# 42.0        1
# 31.0        1
# 30.0        1
# 29.0        1
# 34.0        1
# 36.0        1
# Name: count, dtype: int64
# 이식된 배아 수
# 2.0    39043
# 1.0    32908
# 0.0    12805
# 3.0     3135
# Name: count, dtype: int64
# 미세주입 배아 이식 수
# 0.0    48487
# 2.0    21117
# 1.0    16432
# 3.0     1855
# Name: count, dtype: int64
# 저장된 배아 수
# 0.0     58706
# 2.0      7117
# 1.0      7082
# 3.0      4728
# 4.0      3289
# 5.0      2046
# 6.0      1414
# 7.0       878
# 8.0       686
# 9.0       462
# 10.0      335
# 11.0      275
# 12.0      163
# 13.0      131
# 14.0      129
# 16.0       90
# 15.0       75
# 18.0       53
# 17.0       49
# 19.0       43
# 20.0       31
# 22.0       31
# 21.0       22
# 23.0       17
# 24.0        9
# 26.0        8
# 28.0        4
# 25.0        3
# 27.0        3
# 34.0        3
# 36.0        1
# 37.0        1
# 31.0        1
# 29.0        1
# 30.0        1
# 45.0        1
# 38.0        1
# 33.0        1
# 48.0        1
# Name: count, dtype: int64
# 미세주입 후 저장된 배아 수
# 0.0     71794
# 1.0      4297
# 2.0      4088
# 3.0      2637
# 4.0      1750
# 5.0      1032
# 6.0       680
# 7.0       408
# 8.0       322
# 9.0       212
# 10.0      153
# 11.0      128
# 12.0       77
# 14.0       66
# 13.0       51
# 16.0       46
# 15.0       33
# 17.0       25
# 18.0       24
# 19.0       20
# 20.0       11
# 22.0        9
# 21.0        7
# 23.0        6
# 24.0        5
# 26.0        5
# 28.0        2
# 27.0        1
# 25.0        1
# 34.0        1
# Name: count, dtype: int64
# 해동된 배아 수
# 0.0     73931
# 1.0      4458
# 2.0      4143
# 3.0      1948
# 4.0      1128
# 5.0       673
# 6.0       539
# 7.0       290
# 8.0       263
# 9.0       172
# 10.0      113
# 12.0       59
# 11.0       55
# 13.0       34
# 14.0       23
# 15.0       15
# 16.0       10
# 17.0        8
# 18.0        7
# 19.0        6
# 21.0        4
# 23.0        3
# 20.0        3
# 22.0        2
# 24.0        2
# 26.0        1
# 27.0        1
# Name: count, dtype: int64
# 해동 난자 수
# 0.0     87397
# 6.0        70
# 8.0        65
# 7.0        48
# 4.0        39
# 9.0        35
# 10.0       34
# 5.0        34
# 12.0       24
# 11.0       24
# 3.0        21
# 2.0        19
# 13.0       18
# 14.0       10
# 16.0        9
# 17.0        9
# 15.0        8
# 1.0         8
# 19.0        6
# 18.0        4
# 20.0        2
# 25.0        2
# 21.0        1
# 24.0        1
# 23.0        1
# 29.0        1
# 22.0        1
# Name: count, dtype: int64
# 수집된 신선 난자 수
# 0.0     18680
# 8.0      4722
# 7.0      4644
# 9.0      4601
# 10.0     4507
# 6.0      4471
# 11.0     4119
# 5.0      4023
# 12.0     3818
# 4.0      3611
# 13.0     3463
# 14.0     3264
# 3.0      2870
# 15.0     2762
# 16.0     2426
# 2.0      2311
# 17.0     2009
# 18.0     1745
# 1.0      1700
# 19.0     1456
# 20.0     1216
# 21.0      936
# 22.0      827
# 23.0      650
# 24.0      533
# 25.0      454
# 26.0      391
# 27.0      286
# 28.0      243
# 29.0      191
# 30.0      159
# 32.0      133
# 31.0      122
# 33.0       93
# 34.0       79
# 35.0       63
# 36.0       52
# 37.0       44
# 38.0       35
# 39.0       30
# 51.0       25
# 40.0       24
# 42.0       22
# 41.0       17
# 44.0       15
# 43.0       10
# 45.0        9
# 49.0        7
# 46.0        7
# 47.0        6
# 50.0        5
# 48.0        5
# Name: count, dtype: int64
# 저장된 신선 난자 수
# 0.0     87000
# 7.0        79
# 5.0        76
# 4.0        65
# 8.0        64
# 6.0        62
# 3.0        59
# 10.0       48
# 2.0        48
# 11.0       45
# 9.0        44
# 1.0        40
# 12.0       40
# 14.0       37
# 13.0       25
# 16.0       23
# 15.0       21
# 17.0       19
# 18.0       18
# 19.0       12
# 21.0       10
# 20.0       10
# 25.0        9
# 22.0        7
# 23.0        6
# 26.0        4
# 24.0        4
# 27.0        3
# 33.0        2
# 28.0        2
# 39.0        2
# 36.0        2
# 44.0        1
# 34.0        1
# 32.0        1
# 29.0        1
# 35.0        1
# Name: count, dtype: int64
# 혼합된 난자 수
# 0.0     16113
# 7.0      5734
# 6.0      5694
# 5.0      5452
# 8.0      5425
# 9.0      4950
# 4.0      4909
# 10.0     4635
# 11.0     3995
# 3.0      3953
# 12.0     3551
# 2.0      3163
# 13.0     3132
# 14.0     2645
# 1.0      2291
# 15.0     2278
# 16.0     1862
# 17.0     1524
# 18.0     1266
# 19.0     1061
# 20.0      795
# 21.0      658
# 22.0      522
# 23.0      406
# 24.0      366
# 25.0      276
# 26.0      249
# 27.0      188
# 28.0      142
# 29.0      113
# 30.0       98
# 31.0       85
# 32.0       71
# 33.0       55
# 34.0       47
# 36.0       32
# 35.0       29
# 38.0       20
# 37.0       19
# 41.0       13
# 40.0       12
# 44.0       10
# 51.0       10
# 42.0        9
# 39.0        8
# 45.0        6
# 43.0        6
# 46.0        5
# 48.0        3
# 49.0        2
# 47.0        2
# 50.0        1
# Name: count, dtype: int64
# 파트너 정자와 혼합된 난자 수
# 0.0     21848
# 7.0      5244
# 6.0      5237
# 8.0      5053
# 5.0      5021
# 9.0      4535
# 4.0      4457
# 10.0     4278
# 11.0     3711
# 3.0      3585
# 12.0     3295
# 13.0     2886
# 2.0      2839
# 14.0     2456
# 15.0     2116
# 1.0      2046
# 16.0     1750
# 17.0     1414
# 18.0     1175
# 19.0      976
# 20.0      745
# 21.0      621
# 22.0      490
# 23.0      376
# 24.0      338
# 25.0      256
# 26.0      222
# 27.0      181
# 28.0      130
# 29.0      106
# 30.0       88
# 31.0       81
# 32.0       69
# 33.0       54
# 34.0       42
# 36.0       30
# 35.0       26
# 37.0       18
# 38.0       17
# 41.0       13
# 40.0       12
# 44.0        9
# 42.0        8
# 51.0        8
# 39.0        8
# 46.0        5
# 43.0        5
# 45.0        4
# 48.0        3
# 49.0        2
# 47.0        1
# 50.0        1
# Name: count, dtype: int64
# 기증자 정자와 혼합된 난자 수
# 0.0     82415
# 7.0       489
# 6.0       458
# 4.0       457
# 5.0       443
# 9.0       399
# 3.0       376
# 8.0       357
# 10.0      341
# 2.0       328
# 11.0      274
# 1.0       247
# 12.0      243
# 13.0      218
# 14.0      167
# 15.0      131
# 17.0      100
# 16.0       94
# 18.0       73
# 19.0       65
# 20.0       45
# 21.0       29
# 22.0       25
# 23.0       22
# 24.0       19
# 26.0       19
# 25.0       14
# 28.0        8
# 27.0        5
# 30.0        5
# 29.0        5
# 31.0        4
# 35.0        2
# 36.0        2
# 45.0        2
# 38.0        2
# 33.0        1
# 43.0        1
# 37.0        1
# 44.0        1
# 42.0        1
# 32.0        1
# 34.0        1
# 51.0        1
# Name: count, dtype: int64
# 난자 출처
# 본인 제공     82397
# 기증 제공      5494
# 알 수 없음     2176
# Name: count, dtype: int64
# 정자 출처
# 배우자 제공         80569
# 기증 제공           9460
# 미할당               33
# 배우자 및 기증 제공        5
# Name: count, dtype: int64
# 난자 기증자 나이
# 알 수 없음     85173
# 만31-35세     2289
# 만26-30세     1669
# 만21-25세      817
# 만20세 이하      119
# Name: count, dtype: int64
# 정자 기증자 나이
# 알 수 없음     81043
# 만21-25세     1988
# 만36-40세     1887
# 만26-30세     1828
# 만31-35세     1643
# 만41-45세     1299
# 만20세 이하      379
# Name: count, dtype: int64
# 동결 배아 사용 여부
# 0.0    74022
# 1.0    13869
# Name: count, dtype: int64
# 신선 배아 사용 여부
# 1.0    74092
# 0.0    13799
# Name: count, dtype: int64
# 기증 배아 사용 여부
# 0.0    87087
# 1.0      804
# Name: count, dtype: int64
# 대리모 여부
# 0.0    87506
# 1.0      385
# Name: count, dtype: int64
# PGD 시술 여부
# 1.0    781
# Name: count, dtype: int64
# PGS 시술 여부
# 1.0    671
# Name: count, dtype: int64
# 난자 채취 경과일
# 0.0    70118
# Name: count, dtype: int64
# 난자 해동 경과일
# 0.0    491
# 5.0      1
# Name: count, dtype: int64
# 난자 혼합 경과일
# 0.0    71213
# 1.0      201
# 2.0       38
# 3.0       23
# 5.0        5
# 4.0        5
# 6.0        2
# 7.0        1
# Name: count, dtype: int64
# 배아 이식 경과일
# 5.0    28790
# 3.0    20630
# 2.0    12206
# 0.0     8538
# 1.0     2094
# 4.0     1570
# 6.0      960
# 7.0       33
# Name: count, dtype: int64
# 배아 해동 경과일
# 0.0    13751
# 3.0       59
# 2.0       57
# 5.0       55
# 1.0       17
# 6.0        7
# 4.0        4
# Name: count, dtype: int64

# %%
print(drop_columns2)
train.drop(columns=drop_columns2, inplace=True)
test.drop(columns=drop_columns2, inplace=True)

train.shape, test.shape
# Out:
# ['착상 전 유전 검사 사용 여부', '불임 원인 - 여성 요인', 'PGD 시술 여부', 'PGS 시술 여부', '난자 채취 경과일']
# ((256351, 63), (90067, 62))

# %%
cat_to_int_dict = {'6회 이상' : 6, '5회' : 5, '4회' : 4, '3회' : 3, '2회' : 2, '1회' : 1, '0회' : 0}

cat_to_int_columns = ['총 시술 횟수', '클리닉 내 총 시술 횟수', 'IVF 시술 횟수','DI 시술 횟수',
                      '총 임신 횟수', 'IVF 임신 횟수', 'DI 임신 횟수', '총 출산 횟수', 'IVF 출산 횟수','DI 출산 횟수']
for col in cat_to_int_columns:
  train[col] = train[col].map(cat_to_int_dict)
  test[col] = test[col].map(cat_to_int_dict)

# %%
train.loc[train['불임 원인 - 정자 농도'] == 1]['임신 성공 여부'].value_counts()
# Out:
# 임신 성공 여부
# 0    207
# 1     69
# Name: count, dtype: int64

# %%
X = train.drop('임신 성공 여부', axis=1)
y = train['임신 성공 여부']

# categorical_columns = ["시술 시기 코드","시술 당시 나이", "시술 유형", "특정 시술 유형","배란 자극 여부",
                      #  "단일 배아 이식 여부","착상 전 유전 진단 사용 여부",
                      #  "남성 주 불임 원인","남성 부 불임 원인","여성 주 불임 원인","여성 부 불임 원인",
                      #  "부부 주 불임 원인","부부 부 불임 원인","불명확 불임 원인","불임 원인 - 난관 질환",
                      #  "불임 원인 - 남성 요인","불임 원인 - 배란 장애","불임 원인 - 자궁경부 문제","불임 원인 - 자궁내막증",
                      #  "불임 원인 - 정자 농도","불임 원인 - 정자 면역학적 요인","불임 원인 - 정자 운동성","불임 원인 - 정자 형태",
                      #  "배아 생성 주요 이유","총 시술 횟수","클리닉 내 총 시술 횟수","IVF 시술 횟수","DI 시술 횟수",
                      #  "총 임신 횟수","IVF 임신 횟수","DI 임신 횟수","총 출산 횟수","IVF 출산 횟수","DI 출산 횟수",
                      #  "난자 출처","정자 출처","난자 기증자 나이","정자 기증자 나이",
                      #  "동결 배아 사용 여부","신선 배아 사용 여부","기증 배아 사용 여부","대리모 여부"]
categorical_columns =  ["시술 시기 코드","시술 당시 나이", "시술 유형", "특정 시술 유형","배란 자극 여부",
                       "단일 배아 이식 여부","착상 전 유전 진단 사용 여부",
                       "남성 주 불임 원인","남성 부 불임 원인","여성 주 불임 원인","여성 부 불임 원인",
                       "부부 주 불임 원인","부부 부 불임 원인","불명확 불임 원인","불임 원인 - 난관 질환",
                       "불임 원인 - 남성 요인","불임 원인 - 배란 장애","불임 원인 - 자궁내막증","불임 원인 - 정자 농도",
                       "배아 생성 주요 이유","난자 출처","정자 출처","난자 기증자 나이","정자 기증자 나이",
                       "동결 배아 사용 여부","신선 배아 사용 여부","기증 배아 사용 여부","대리모 여부",
                        '배란 유도 유형',  '불임 원인 - 자궁경부 문제', '불임 원인 - 정자 면역학적 요인', '불임 원인 - 정자 운동성', '불임 원인 - 정자 형태']


for col in categorical_columns:
    # mode_value = X[col].mode()[0]
    # X[col].fillna(mode_value, inplace=True)  # 결측치 대체
    # test[col].fillna(mode_value, inplace = True)

    X[col] = X[col].astype(str)
    test[col] = test[col].astype(str)

numeric_columns = ["총 시술 횟수","클리닉 내 총 시술 횟수","IVF 시술 횟수","DI 시술 횟수",
                       "총 임신 횟수","IVF 임신 횟수","DI 임신 횟수","총 출산 횟수","IVF 출산 횟수","DI 출산 횟수",
                   '임신 시도 또는 마지막 임신 경과 연수', "총 생성 배아 수","미세주입된 난자 수","미세주입에서 생성된 배아 수",
                   "이식된 배아 수","미세주입 배아 이식 수","저장된 배아 수","미세주입 후 저장된 배아 수",
                   "해동된 배아 수","해동 난자 수","수집된 신선 난자 수","저장된 신선 난자 수","혼합된 난자 수",
                   "파트너 정자와 혼합된 난자 수","기증자 정자와 혼합된 난자 수",
                   '난자 해동 경과일', "난자 혼합 경과일","배아 이식 경과일", '배아 해동 경과일']

# numeric_columns = ["총 생성 배아 수","미세주입된 난자 수","미세주입에서 생성된 배아 수",
#                    "이식된 배아 수","미세주입 배아 이식 수","저장된 배아 수","미세주입 후 저장된 배아 수",
#                    "수집된 신선 난자 수","혼합된 난자 수","파트너 정자와 혼합된 난자 수",
#                    "기증자 정자와 혼합된 난자 수","배아 이식 경과일"]

for col in numeric_columns:
    mode_value = X[col].mode()[0]  # 최빈값 구하기
    X[col].fillna(mode_value, inplace=True)  # 결측치 대체
    test[col].fillna(mode_value, inplace = True)
# Out:
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X[col].fillna(mode_value, inplace=True)  # 결측치 대체
# /var/folders/_2/7d52k4j5451f0ytscvrz28k40000gn/T/ipykernel_1352/502885209.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test[col].fillna(mode_value, inplace = True)

# %%
# 분포 정규화 (왜도가 큰 변수에 대해 로그 변환)
skew_threshold = 1  # 왜도 임계값
for col in numeric_columns:
    skew_val = X[col].skew()
    if skew_val > skew_threshold:
        X[col] = np.log1p(X[col])
        test[col] = np.log1p(test[col])
        print(f"{col}: skewness {skew_val:.2f} -> 로그 변환 적용")
# Out:
# 총 시술 횟수: skewness 1.10 -> 로그 변환 적용
# 클리닉 내 총 시술 횟수: skewness 1.51 -> 로그 변환 적용
# IVF 시술 횟수: skewness 1.21 -> 로그 변환 적용
# DI 시술 횟수: skewness 5.43 -> 로그 변환 적용
# 총 임신 횟수: skewness 2.34 -> 로그 변환 적용
# IVF 임신 횟수: skewness 2.42 -> 로그 변환 적용
# DI 임신 횟수: skewness 11.82 -> 로그 변환 적용
# 총 출산 횟수: skewness 2.52 -> 로그 변환 적용
# IVF 출산 횟수: skewness 2.59 -> 로그 변환 적용
# DI 출산 횟수: skewness 12.75 -> 로그 변환 적용
# 임신 시도 또는 마지막 임신 경과 연수: skewness 8.95 -> 로그 변환 적용
# 총 생성 배아 수: skewness 1.20 -> 로그 변환 적용
# 미세주입된 난자 수: skewness 1.52 -> 로그 변환 적용
# 미세주입에서 생성된 배아 수: skewness 1.77 -> 로그 변환 적용
# 저장된 배아 수: skewness 3.83 -> 로그 변환 적용
# 미세주입 후 저장된 배아 수: skewness 5.40 -> 로그 변환 적용
# 해동된 배아 수: skewness 5.19 -> 로그 변환 적용
# 해동 난자 수: skewness 18.56 -> 로그 변환 적용
# 저장된 신선 난자 수: skewness 15.87 -> 로그 변환 적용
# 혼합된 난자 수: skewness 1.00 -> 로그 변환 적용
# 파트너 정자와 혼합된 난자 수: skewness 1.04 -> 로그 변환 적용
# 기증자 정자와 혼합된 난자 수: skewness 6.11 -> 로그 변환 적용
# 난자 해동 경과일: skewness 358.01 -> 로그 변환 적용
# 난자 혼합 경과일: skewness 34.01 -> 로그 변환 적용
# 배아 해동 경과일: skewness 26.43 -> 로그 변환 적용

# %%
def make_feature(df):
  #df['난자 활용률'] = df['미세주입된 난자 수'] / (df['수집된 신선 난자 수'] + df['해동 난자 수'] + 1)
  df['미세주입 배아 생성률'] = df['미세주입에서 생성된 배아 수'] / (df['미세주입된 난자 수'] + 1)
  df['미세주입 배아 이식률'] = df['미세주입 배아 이식 수'] / (df['미세주입에서 생성된 배아 수'] + 1)
  df['배아 이식률'] = df['이식된 배아 수'] / (df['총 생성 배아 수'] + 1)
  df['저장 배아 비율'] = df['저장된 배아 수'] / (df['총 생성 배아 수'] + 1)
  df['해동 배아 생존율'] = df['해동된 배아 수'] / (df['저장된 배아 수'] + 1)
  df['파트너 정자 혼합 비율'] = df['파트너 정자와 혼합된 난자 수'] / (df['혼합된 난자 수'] + 1)
  #df['미세주입 배아 이식 비율'] = df['미세주입 배아 이식 수'] / (df['이식된 배아 수'] + 1)

  df['임신 성공률'] = df['총 임신 횟수'] / (df['총 시술 횟수'] + 1)
  df['IVF 시술 성공률'] = df['IVF 임신 횟수'] / (df['IVF 시술 횟수'] + 1)
  df['DI 시술 성공률'] = df['DI 임신 횟수'] / (df['DI 시술 횟수'] + 1)
  # df['출산율'] = df['총 출산 횟수'] / (df['총 임신 횟수'] + 1)
  # df['IVF 출산율'] = df['IVF 출산 횟수'] / (df['IVF 임신 횟수'] + 1)
  # df['DI 출산율'] = df['DI 출산 횟수'] / (df['DI 임신 횟수'] + 1)
  # df['시술 기준 출산 성공률'] = df['총 출산 횟수'] / (df['총 시술 횟수'] + 1)

  return df

# %%
X = make_feature(X)
test = make_feature(test)

X.shape, test.shape
# Out:
# ((256351, 71), (90067, 71))

# %%
test_pred_total = []
scores = []
cv = StratifiedKFold(n_splits = 10, random_state = 42, shuffle=True)

for idx, (train_idx, val_idx) in enumerate(cv.split(X, y)):
    print('='*50)
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    model = CatBoostClassifier(auto_class_weights='Balanced', eval_metric='AUC', random_state=42)
    model.fit(
        X_train,
        y_train,
        cat_features=categorical_columns,
        early_stopping_rounds= 300,
        eval_set=[(X_val,y_val)],
        verbose = 100
        )

    scores.append(model.get_best_score()["validation"]["AUC"])

    test_pred = model.predict_proba(test)[:, 1]
    test_pred_total.append(test_pred)
# Out:
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7191414	best: 0.7191414 (0)	total: 76.3ms	remaining: 1m 16s
# 100:	test: 0.7424009	best: 0.7424262 (99)	total: 7.32s	remaining: 1m 5s
# 200:	test: 0.7427889	best: 0.7430931 (155)	total: 15.4s	remaining: 1m 1s
# 300:	test: 0.7426165	best: 0.7430931 (155)	total: 24s	remaining: 55.7s
# 400:	test: 0.7423939	best: 0.7430931 (155)	total: 31.8s	remaining: 47.6s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7430930921
# bestIteration = 155
#
# Shrink model to first 156 iterations.
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7117283	best: 0.7117283 (0)	total: 69.4ms	remaining: 1m 9s
# 100:	test: 0.7318983	best: 0.7319154 (97)	total: 7.45s	remaining: 1m 6s
# 200:	test: 0.7328416	best: 0.7328537 (199)	total: 14.9s	remaining: 59.3s
# 300:	test: 0.7322176	best: 0.7328537 (199)	total: 22.5s	remaining: 52.2s
# 400:	test: 0.7321369	best: 0.7328537 (199)	total: 29.9s	remaining: 44.7s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7328537137
# bestIteration = 199
#
# Shrink model to first 200 iterations.
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7180201	best: 0.7180201 (0)	total: 63.4ms	remaining: 1m 3s
# 100:	test: 0.7383196	best: 0.7383196 (100)	total: 6.78s	remaining: 1m
# 200:	test: 0.7394818	best: 0.7394818 (200)	total: 14.2s	remaining: 56.3s
# 300:	test: 0.7396094	best: 0.7396094 (300)	total: 21.6s	remaining: 50.2s
# 400:	test: 0.7395260	best: 0.7396635 (328)	total: 29.1s	remaining: 43.5s
# 500:	test: 0.7393628	best: 0.7396635 (328)	total: 36.8s	remaining: 36.6s
# 600:	test: 0.7390093	best: 0.7396635 (328)	total: 44.3s	remaining: 29.4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7396635166
# bestIteration = 328
#
# Shrink model to first 329 iterations.
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7259111	best: 0.7259111 (0)	total: 62.9ms	remaining: 1m 2s
# 100:	test: 0.7458447	best: 0.7458447 (100)	total: 6.91s	remaining: 1m 1s
# 200:	test: 0.7463338	best: 0.7463778 (196)	total: 14.4s	remaining: 57.3s
# 300:	test: 0.7463170	best: 0.7463778 (196)	total: 21.9s	remaining: 50.8s
# 400:	test: 0.7459366	best: 0.7463850 (312)	total: 29.4s	remaining: 43.9s
# 500:	test: 0.7458053	best: 0.7463850 (312)	total: 36.8s	remaining: 36.7s
# 600:	test: 0.7457861	best: 0.7463850 (312)	total: 44.4s	remaining: 29.5s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7463850243
# bestIteration = 312
#
# Shrink model to first 313 iterations.
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7248212	best: 0.7248212 (0)	total: 61.5ms	remaining: 1m 1s
# 100:	test: 0.7419930	best: 0.7420170 (98)	total: 6.99s	remaining: 1m 2s
# 200:	test: 0.7426273	best: 0.7427023 (185)	total: 14.4s	remaining: 57.1s
# 300:	test: 0.7427075	best: 0.7427120 (291)	total: 21.9s	remaining: 50.8s
# 400:	test: 0.7427607	best: 0.7428769 (369)	total: 29.3s	remaining: 43.8s
# 500:	test: 0.7425431	best: 0.7428769 (369)	total: 36.8s	remaining: 36.7s
# 600:	test: 0.7422981	best: 0.7428769 (369)	total: 44.2s	remaining: 29.4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7428769012
# bestIteration = 369
#
# Shrink model to first 370 iterations.
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7135073	best: 0.7135073 (0)	total: 60.7ms	remaining: 1m
# 100:	test: 0.7361758	best: 0.7361758 (100)	total: 6.67s	remaining: 59.4s
# 200:	test: 0.7373034	best: 0.7373647 (196)	total: 14.1s	remaining: 56.2s
# 300:	test: 0.7374712	best: 0.7374712 (300)	total: 21.6s	remaining: 50.2s
# 400:	test: 0.7371069	best: 0.7374712 (300)	total: 29.2s	remaining: 43.7s
# 500:	test: 0.7372620	best: 0.7374712 (300)	total: 36.7s	remaining: 36.6s
# 600:	test: 0.7368742	best: 0.7374712 (300)	total: 44.3s	remaining: 29.4s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7374712027
# bestIteration = 300
#
# Shrink model to first 301 iterations.
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7083357	best: 0.7083357 (0)	total: 62.6ms	remaining: 1m 2s
# 100:	test: 0.7354762	best: 0.7354762 (100)	total: 6.86s	remaining: 1m 1s
# 200:	test: 0.7365568	best: 0.7366231 (172)	total: 14.3s	remaining: 56.8s
# 300:	test: 0.7368867	best: 0.7369735 (278)	total: 21.6s	remaining: 50.3s
# 400:	test: 0.7365807	best: 0.7369735 (278)	total: 29.2s	remaining: 43.5s
# 500:	test: 0.7364372	best: 0.7369735 (278)	total: 36.7s	remaining: 36.5s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.736973472
# bestIteration = 278
#
# Shrink model to first 279 iterations.
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7150486	best: 0.7150486 (0)	total: 75ms	remaining: 1m 14s
# 100:	test: 0.7395374	best: 0.7395374 (100)	total: 6.9s	remaining: 1m 1s
# 200:	test: 0.7396443	best: 0.7398119 (148)	total: 14.2s	remaining: 56.5s
# 300:	test: 0.7392687	best: 0.7398119 (148)	total: 21.7s	remaining: 50.5s
# 400:	test: 0.7390520	best: 0.7398119 (148)	total: 29.2s	remaining: 43.6s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7398119488
# bestIteration = 148
#
# Shrink model to first 149 iterations.
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7187101	best: 0.7187101 (0)	total: 63.5ms	remaining: 1m 3s
# 100:	test: 0.7397038	best: 0.7397092 (99)	total: 6.77s	remaining: 1m
# 200:	test: 0.7403951	best: 0.7407110 (174)	total: 14.2s	remaining: 56.5s
# 300:	test: 0.7402353	best: 0.7407110 (174)	total: 21.9s	remaining: 50.9s
# 400:	test: 0.7398554	best: 0.7407110 (174)	total: 29.5s	remaining: 44.1s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7407109972
# bestIteration = 174
#
# Shrink model to first 175 iterations.
# ==================================================
# Learning rate set to 0.121504
# 0:	test: 0.7213301	best: 0.7213301 (0)	total: 62.7ms	remaining: 1m 2s
# 100:	test: 0.7397467	best: 0.7397638 (97)	total: 7.31s	remaining: 1m 5s
# 200:	test: 0.7404561	best: 0.7405580 (150)	total: 14.7s	remaining: 58.5s
# 300:	test: 0.7404666	best: 0.7405580 (150)	total: 22s	remaining: 51.2s
# 400:	test: 0.7402847	best: 0.7405580 (150)	total: 29.4s	remaining: 44s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7405580148
# bestIteration = 150
#
# Shrink model to first 151 iterations.

# %%
np.mean(scores)
# Out:
# 0.7400397883458353

# %%
test_pred_total = np.mean(test_pred_total, axis=0)

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission['probability'] = test_pred_total

# %%
sample_submission.to_csv('./sunghyun_catboost+log.csv', index=False)
